# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
imagem = cv2.imread('/content/drive/MyDrive/imagens/microcalcif_mamogr.jpg')
imagem2 = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

plt.imshow(imagem)
plt.show()


kernel = np.array([[1,1,1],
                   [1,-8,1],
                   [1,1,1]])

kernelBlur = np.array([[1,1,1],
                   [1,1,1],
                   [1,1,1]])

img_filt = cv2.filter2D(imagem, -1, kernel)
img_blur = cv2.filter2D(img_filt, -1, kernelBlur)

#img_normalizada = (img_filt - np.min(img_filt)) / (np.max(img_filt) - np.min(img_filt))


plt.imshow(img_filt)
plt.show()
plt.imshow(img_blur)
plt.show()
